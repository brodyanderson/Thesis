# %% [markdown]
# <a href="https://colab.research.google.com/github/brodyanderson/Thesis/blob/main/Thesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy import stats
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.linear_model import LogisticRegressionCV

# %%
url = 'https://raw.githubusercontent.com/brodyanderson/Thesis/main/Thesis_Final.csv'
injury_df = pd.read_csv(url, sep=",")

# %%
injury_df.shape
injury_df.head()
injury_df['Injury'] == 1).sum()
(injury_df['Injury'] == 0).sum()
